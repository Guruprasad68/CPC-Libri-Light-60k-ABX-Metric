# %% [markdown]
# ## Evaluating CPC Libri-Light 60k models using minimal-pair ABX metric using https://github.com/facebookresearch/libri-light
#
# ### Before running:
# ### CODE CHANGE NEEDED
# ### L168 in eval_ABX.py to state_dict = torch.load(args.path_checkpoint,map_location='cuda:0')

# %%
# !git clone https://github.com/facebookresearch/libri-light
# Out:
# Cloning into 'libri-light'...
# remote: Enumerating objects: 173, done.
# remote: Counting objects: 100% (18/18), done.
# remote: Compressing objects: 100% (16/16), done.
# remote: Total 173 (delta 6), reused 7 (delta 2), pack-reused 155
# Receiving objects: 100% (173/173), 371.29 KiB | 16.14 MiB/s, done.
# Resolving deltas: 100% (60/60), done.

# %%
# %cd libri-light/eval/ABX_src
# Out:
# /content/libri-light/eval/ABX_src

# %%
# !python setup.py build_ext --inplace
# Out:
# Compiling dtw.pyx because it changed.
# [1/1] Cythonizing dtw.pyx
# /usr/local/lib/python3.7/dist-packages/Cython/Compiler/Main.py:369: FutureWarning: Cython directive 'language_level' not set, using 2 for now (Py2). This will change in a later release! File: /content/libri-light/eval/ABX_src/dtw.pyx
#   tree = Parsing.p_module(s, pxd, full_module_name)
# running build_ext
# building 'ABX_src.dtw' extension
# creating build
# creating build/temp.linux-x86_64-3.7
# x86_64-linux-gnu-gcc -pthread -Wno-unused-result -Wsign-compare -DNDEBUG -g -fwrapv -O2 -Wall -g -fstack-protector-strong -Wformat -Werror=format-security -g -fwrapv -O2 -g -fstack-protector-strong -Wformat -Werror=format-security -Wdate-time -D_FORTIFY_SOURCE=2 -fPIC -I/usr/local/lib/python3.7/dist-packages/numpy/core/include -I/usr/include/python3.7m -c dtw.c -o build/temp.linux-x86_64-3.7/dtw.o
# In file included from /usr/local/lib/python3.7/dist-packages/numpy/core/include/numpy/ndarraytypes.h:1969:0,
# ...

# %%
# !pip install nose
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 154 kB 29.5 MB/s
# ...

# %%
# !nosetests -d
# Out:
# 100% (4 of 4) |###########################| Elapsed Time: 0:00:00 Time:  0:00:00
# 100% (2 of 2) |###########################| Elapsed Time: 0:00:00 Time:  0:00:00
# .......
# ----------------------------------------------------------------------
# Ran 10 tests in 0.483s
#
# OK

# %%
#Downloading the item files
# %cd ..
# !wget https://dl.fbaipublicfiles.com/librilight/data/ABX_data.tgz
# !tar -xzvf ABX_data.tgz
# Out:
# /content/libri-light/eval
# --2022-10-21 12:01:43--  https://dl.fbaipublicfiles.com/librilight/data/ABX_data.tgz
# Resolving dl.fbaipublicfiles.com (dl.fbaipublicfiles.com)... 172.67.9.4, 104.22.74.142, 104.22.75.142, ...
# Connecting to dl.fbaipublicfiles.com (dl.fbaipublicfiles.com)|172.67.9.4|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 5192821 (5.0M) [application/gzip]
# Saving to: ‘ABX_data.tgz’
#
# ABX_data.tgz        100%[===================>]   4.95M  8.29MB/s    in 0.6s
#
# 2022-10-21 12:01:44 (8.29 MB/s) - ‘ABX_data.tgz’ saved [5192821/5192821]
#
# ABX_data/
# ABX_data/dev-clean.item
# ABX_data/dev-other.item
# ABX_data/test-clean.item
# ABX_data/test-other.item

# %%
#Downloading the audio files of librispeech from Open-SLR
# !wget https://us.openslr.org/resources/12/dev-clean.tar.gz && tar -xzvf dev-clean.tar.gz
# !wget https://us.openslr.org/resources/12/dev-other.tar.gz && tar -xzvf dev-other.tar.gz
# !wget https://us.openslr.org/resources/12/test-other.tar.gz && tar -xzvf test-other.tar.gz
# !wget https://us.openslr.org/resources/12/test-clean.tar.gz && tar -xzvf test-clean.tar.gz
# Out:
# Streaming output truncated to the last 5000 lines.
# LibriSpeech/test-other/3528/168669/3528-168669-0000.flac
# LibriSpeech/test-other/3528/168669/3528-168669-0125.flac
# LibriSpeech/test-other/3528/168669/3528-168669-0087.flac
# LibriSpeech/test-other/3528/168669/3528-168669-0105.flac
# LibriSpeech/test-other/3528/168669/3528-168669-0026.flac
# LibriSpeech/test-other/3528/168669/3528-168669-0050.flac
# LibriSpeech/test-other/3528/168669/3528-168669-0072.flac
# LibriSpeech/test-other/3528/168669/3528-168669-0032.flac
# LibriSpeech/test-other/3528/168669/3528-168669-0052.flac
# LibriSpeech/test-other/3528/168669/3528-168669-0114.flac
# LibriSpeech/test-other/3528/168669/3528-168669-0095.flac
# LibriSpeech/test-other/3528/168669/3528-168669-0113.flac
# LibriSpeech/test-other/3528/168669/3528-168669-0071.flac
# LibriSpeech/test-other/3528/168669/3528-168669-0029.flac
# LibriSpeech/test-other/3528/168669/3528-168669-0081.flac
# LibriSpeech/test-other/3528/168669/3528-168669-0043.flac
# ...

# %%
# !wget https://dl.fbaipublicfiles.com/librilight/CPC_checkpoints/60k_epoch4-d0f474de.pt
# Out:
# --2022-10-21 12:02:40--  https://dl.fbaipublicfiles.com/librilight/CPC_checkpoints/60k_epoch4-d0f474de.pt
# Resolving dl.fbaipublicfiles.com (dl.fbaipublicfiles.com)... 104.22.74.142, 104.22.75.142, 172.67.9.4, ...
# Connecting to dl.fbaipublicfiles.com (dl.fbaipublicfiles.com)|104.22.74.142|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 7379446 (7.0M) [application/octet-stream]
# Saving to: ‘60k_epoch4-d0f474de.pt’
#
# 60k_epoch4-d0f474de 100%[===================>]   7.04M  11.4MB/s    in 0.6s
#
# 2022-10-21 12:02:41 (11.4 MB/s) - ‘60k_epoch4-d0f474de.pt’ saved [7379446/7379446]

# %%
#Dev-clean
# !python eval_ABX.py LibriSpeech/dev-clean/  ABX_data/dev-clean.item --file_extension .flac --out $PWD --path_checkpoint 60k_epoch4-d0f474de.pt
# Out:
# Building the input features...
# 100% (2703 of 2703) |#####################| Elapsed Time: 0:00:48 Time:  0:00:48
# ...done
# tcmalloc: large alloc 3802652672 bytes == 0x118e92000 @  0x7faca53d3b6b 0x7faca53f3379 0x7fac35950d57 0x7fac3593ebc3 0x7fac5f8496af 0x7fac5f84a020 0x7fac5f84a074 0x7fac5f84a1bf 0x7fac605d182b 0x7fac60634d42 0x7fac5fd74e37 0x7fac605da89e 0x7fac605da923 0x7fac600af49c 0x7fac61629fe5 0x7fac6162a7b6 0x7fac600eb565 0x7fac87652c92 0x58f795 0x510bf2 0x58fd37 0x50ca37 0x4bac0a 0x53881b 0x5909f6 0x510946 0x5b4ee6 0x58ff2e 0x50d482 0x5b575e 0x58ff2e
# Computing ABX within speakers...
# 100% (117927 of 117927) |#################| Elapsed Time: 0:10:32 Time:  0:10:32
# ...done. ABX within : 0.06068778038024902
# Computing ABX across speakers...
# 100% (1346484 of 1346484) |###############| Elapsed Time: 0:50:42 Time:  0:50:42
# ...done. ABX across : 0.07646167278289795

# %%
#Dev-other
# !python eval_ABX.py LibriSpeech/dev-other/  ABX_data/dev-other.item --file_extension .flac --out $PWD --path_checkpoint 60k_epoch4-d0f474de.pt
# Out:
# Building the input features...
# 100% (2864 of 2864) |#####################| Elapsed Time: 0:00:45 Time:  0:00:45
# ...done
# tcmalloc: large alloc 3314302976 bytes == 0x10eef8000 @  0x7fa9fdfebb6b 0x7fa9fe00b379 0x7fa98e568d57 0x7fa98e556bc3 0x7fa9b84616af 0x7fa9b8462020 0x7fa9b8462074 0x7fa9b84621bf 0x7fa9b91e982b 0x7fa9b924cd42 0x7fa9b898ce37 0x7fa9b91f289e 0x7fa9b91f2923 0x7fa9b8cc749c 0x7fa9ba241fe5 0x7fa9ba2427b6 0x7fa9b8d03565 0x7fa9e026ac92 0x58f795 0x510bf2 0x58fd37 0x50ca37 0x4bac0a 0x53881b 0x5909f6 0x510946 0x5b4ee6 0x58ff2e 0x50d482 0x5b575e 0x58ff2e
# Computing ABX within speakers...
# 100% (107244 of 107244) |#################| Elapsed Time: 0:10:09 Time:  0:10:09
# ...done. ABX within : 0.0795309767127037
# Computing ABX across speakers...
# 100% (1147171 of 1147171) |###############| Elapsed Time: 0:46:06 Time:  0:46:06
# ...done. ABX across : 0.12371094524860382

# %%
#Test-other
# !python eval_ABX.py LibriSpeech/test-other/  ABX_data/test-other.item --file_extension .flac --out $PWD --path_checkpoint 60k_epoch4-d0f474de.pt
# Out:
# Building the input features...
# 100% (2939 of 2939) |#####################| Elapsed Time: 0:00:46 Time:  0:00:46
# ...done
# tcmalloc: large alloc 3357696000 bytes == 0x11279c000 @  0x7fec6680fb6b 0x7fec6682f379 0x7febf6d8cd57 0x7febf6d7abc3 0x7fec20c856af 0x7fec20c86020 0x7fec20c86074 0x7fec20c861bf 0x7fec21a0d82b 0x7fec21a70d42 0x7fec211b0e37 0x7fec21a1689e 0x7fec21a16923 0x7fec214eb49c 0x7fec22a65fe5 0x7fec22a667b6 0x7fec21527565 0x7fec48a8ec92 0x58f795 0x510bf2 0x58fd37 0x50ca37 0x4bac0a 0x53881b 0x5909f6 0x510946 0x5b4ee6 0x58ff2e 0x50d482 0x5b575e 0x58ff2e
# Computing ABX within speakers...
# 100% (106769 of 106769) |#################| Elapsed Time: 0:10:21 Time:  0:10:21
# ...done. ABX within : 0.07923882454633713
# Computing ABX across speakers...
# 100% (1147915 of 1147915) |###############| Elapsed Time: 0:47:11 Time:  0:47:11
# ...done. ABX across : 0.1291208118200302

# %%
#Test-clean
# !python eval_ABX.py LibriSpeech/test-clean/  ABX_data/test-clean.item --file_extension .flac --out $PWD --path_checkpoint 60k_epoch4-d0f474de.pt
# Out:
# Building the input features...
# 100% (2620 of 2620) |#####################| Elapsed Time: 0:00:49 Time:  0:00:49
# ...done
# tcmalloc: large alloc 3723296768 bytes == 0x116390000 @  0x7f52004fdb6b 0x7f520051d379 0x7f5190a7ad57 0x7f5190a68bc3 0x7f51ba9736af 0x7f51ba974020 0x7f51ba974074 0x7f51ba9741bf 0x7f51bb6fb82b 0x7f51bb75ed42 0x7f51bae9ee37 0x7f51bb70489e 0x7f51bb704923 0x7f51bb1d949c 0x7f51bc753fe5 0x7f51bc7547b6 0x7f51bb215565 0x7f51e277cc92 0x58f795 0x510bf2 0x58fd37 0x50ca37 0x4bac0a 0x53881b 0x5909f6 0x510946 0x5b4ee6 0x58ff2e 0x50d482 0x5b575e 0x58ff2e
# Computing ABX within speakers...
# 100% (110040 of 110040) |#################| Elapsed Time: 0:10:32 Time:  0:10:32
# ...done. ABX within : 0.05651046708226204
# Computing ABX across speakers...
# 100% (1234075 of 1234075) |###############| Elapsed Time: 0:50:33 Time:  0:50:33
# ...done. ABX across : 0.0732395201921463
